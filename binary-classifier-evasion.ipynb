# %%
import pickle
import numpy as np

# %%
import sys
sys.hexversion
# Out:
# 34016496

# %%
p = pickle.load(open('waf/testfile', 'rb'))

# %%
vars(p)
# Out:
# {'steps': [('vectorizer',
#    TfidfVectorizer(analyzer='char', binary=False, decode_error=u'strict',
#            dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#            lowercase=True, max_df=1.0, max_features=None, min_df=0.0,
#            ngram_range=(1, 3), norm=u'l2', preprocessor=None, smooth_idf=True,
#            stop_words=None, strip_accents=None, sublinear_tf=True,
#            token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#            vocabulary=None)),
#   ('classifier', LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#              fit_intercept=True, intercept_scaling=1, max_iter=100,
#              multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#              solver='liblinear', tol=0.0001, verbose=0, warm_start=False))]}

# %%
vec = p.steps[0][1]
vec
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=0.0,
#         ngram_range=(1, 3), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=True,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
clf = p.steps[1][1]
clf
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
print(vec.idf_)
# Out:
# [  9.88736885  13.47642797  13.9872536  ...,  13.47642797  14.39271871
#   14.39271871]

# %%
print(clf.coef_)
# Out:
# [[  4.15070949e+00   3.24926942e-02   0.00000000e+00 ...,  -2.32818118e-03
#     0.00000000e+00   0.00000000e+00]]

# %%
term_influence = vec.idf_ * clf.coef_
print(term_influence)
# Out:
# [[  4.10395957e+01   4.37885454e-01   0.00000000e+00 ...,  -3.13755660e-02
#     0.00000000e+00   0.00000000e+00]]

# %%
print(np.argpartition(term_influence, 1))
# Out:
# [[80832 90958     2 ..., 95946 95947 95948]]

# %%
vec.vocabulary_
# Out:
# {u'\x00': 0,
#  u'\x00\x00': 1,
#  u'\x00\x00\x00': 2,
#  u'\x00\x00\x02': 3,
#  u'\x00\x00>': 4,
#  u'\x00\x00i': 5,
#  u'\x00\x00v': 6,
#  u'\x00\x02': 7,
#  u'\x00\x02\x03': 8,
#  u'\x00 ': 9,
#  u'\x00 i': 10,
#  u'\x00 o': 11,
#  u'\x00 s': 12,
#  u'\x00"': 13,
#  u'\x00"<': 14,
#  u'\x00">': 15,
#  u'\x00"q': 16,
#  u'\x00&': 17,
#  u'\x00&c': 18,
#  u'\x00&q': 19,
#  u'\x00*': 20,
#  u'\x00*/': 21,
#  u'\x00.': 22,
#  u'\x00..': 23,
#  u'\x00.c': 24,
#  u'\x00.h': 25,
#  u'\x00.j': 26,
#  u'\x00/': 27,
#  u'\x00/\x00': 28,
#  u'\x00/ ': 29,
#  u'\x00/e': 30,
#  u'\x00/s': 31,
#  u'\x00/t': 32,
#  u'\x00/x': 33,
#  u'\x000': 34,
#  u'\x0000': 35,
#  u'\x00<': 36,
#  u'\x00<q': 37,
#  u'\x00<s': 38,
#  u'\x00=': 39,
#  u'\x00=\x00': 40,
#  u'\x00>': 41,
#  u'\x00> ': 42,
#  u'\x00>a': 43,
#  u'\x00>c': 44,
#  u'\x00>q': 45,
#  u'\x00?': 46,
#  u'\x00?v': 47,
#  u'\x00`': 48,
#  u'\x00` ': 49,
#  u'\x00`&': 50,
#  u'\x00c': 51,
#  u'\x00c\x00': 52,
#  u'\x00co': 53,
#  u'\x00e': 54,
#  u'\x00e ': 55,
#  u'\x00h': 56,
#  u'\x00ht': 57,
#  u'\x00i': 58,
#  u'\x00ip': 59,
#  u'\x00l': 60,
#  u'\x00lo': 61,
#  u'\x00n': 62,
#  u'\x00n=': 63,
#  u'\x00p': 64,
#  u'\x00pt': 65,
#  u'\x00r': 66,
#  u'\x00r\x00': 67,
#  u'\x00ri': 68,
#  u'\x00s': 69,
#  u'\x00sc': 70,
#  u'\x00t': 71,
#  u'\x00t>': 72,
#  u'\x00te': 73,
#  u'\x00v': 74,
#  u'\x00v\x00': 75,
#  u'\x00|': 76,
#  u'\x00| ': 77,
#  u'\x01': 78,
#  u'\x01\x02': 79,
#  u'\x01\x02\x03': 80,
#  u'\x01(': 81,
#  u'\x01(1': 82,
#  u'\x01a': 83,
#  u'\x01an': 84,
#  u'\x01s': 85,
#  u'\x01se': 86,
#  u'\x02': 87,
#  u'\x02\x03': 88,
#  u'\x02\x03\x04': 89,
#  u'\x02\x03)': 90,
#  u'\x03': 91,
#  u'\x03\x04': 92,
#  u'\x03\x04 ': 93,
#  u'\x03"': 94,
#  u'\x03">': 95,
#  u'\x03)': 96,
#  u'\x03)n': 97,
#  u'\x04': 98,
#  u'\x04 ': 99,
#  u'\x04 a': 100,
#  u'\x04a': 101,
#  u'\x04al': 102,
#  u'\x07': 103,
#  u'\x079': 104,
#  u'\x0798': 105,
#  u'\x07a': 106,
#  u'\x07an': 107,
#  u'\x07c': 108,
#  u'\x07co': 109,
#  u'\x08': 110,
#  u'\x08\x00': 111,
#  u'\x08\x00\x00': 112,
#  u'\x08x': 113,
#  u'\x08x ': 114,
#  u'\x08x%': 115,
#  u'\t': 116,
#  u'\t"': 117,
#  u'\t"t': 118,
#  u'\t%': 119,
#  u'\t%>': 120,
#  u'\t(': 121,
#  u'\t(;': 122,
#  u'\t2': 123,
#  u'\t25': 124,
#  u'\t6': 125,
#  u'\t6&': 126,
#  u'\t6.': 127,
#  u'\t<': 128,
#  u'\t<!': 129,
#  u'\t<h': 130,
#  u'\t<i': 131,
#  u'\t<s': 132,
#  u'\t=': 133,
#  u'\t=p': 134,
#  u'\ta': 135,
#  u'\tas': 136,
#  u'\tf': 137,
#  u'\tfo': 138,
#  u'\tfu': 139,
#  u'\tl': 140,
#  u'\tli': 141,
#  u'\to': 142,
#  u'\ton': 143,
#  u'\tp': 144,
#  u'\tp&': 145,
#  u'\tp:': 146,
#  u'\tpu': 147,
#  u'\tr': 148,
#  u'\tri': 149,
#  u'\t}': 150,
#  u'\t}}': 151,
#  u'\n': 152,
#  u'\n"': 153,
#  u'\n"\n': 154,
#  u'\n#': 155,
#  u'\n#b': 156,
#  u'\n#c': 157,
#  u'\n#d': 158,
#  u'\n#e': 159,
#  u'\n#g': 160,
#  u'\n#h': 161,
#  u'\n#i': 162,
#  u'\n#j': 163,
#  u'\n#k': 164,
#  u'\n#l': 165,
#  u'\n#n': 166,
#  u'\n#o': 167,
#  u'\n#p': 168,
#  u'\n#r': 169,
#  u'\n#s': 170,
#  u'\n#u': 171,
#  u'\n#x': 172,
#  u"\n'": 173,
#  u"\n'\n": 174,
#  u'\n(': 175,
#  u'\n(\n': 176,
#  u'\n)': 177,
#  u'\n)\n': 178,
#  u'\n),': 179,
#  u'\n*': 180,
#  u'\n*{': 181,
#  u'\n-': 182,
#  u'\n-_': 183,
#  u'\n.': 184,
#  u'\n.\n': 185,
#  u'\n. ': 186,
#  u'\n/': 187,
#  u'\n/ ': 188,
#  u'\n/*': 189,
#  u'\n/>': 190,
#  u'\n/u': 191,
#  u'\n1': 192,
#  u'\n1,': 193,
#  u'\n:': 194,
#  u'\n:\n': 195,
#  u'\n<': 196,
#  u'\n</': 197,
#  u'\n<h': 198,
#  u'\n=': 199,
#  u'\n=\n': 200,
#  u'\n>': 201,
#  u'\n> ': 202,
#  u'\n><': 203,
#  u'\n>c': 204,
#  u'\n`': 205,
#  u'\n`=': 206,
#  u'\na': 207,
#  u'\na\n': 208,
#  u'\nal': 209,
#  u'\nas': 210,
#  u'\nb': 211,
#  u'\nbc': 212,
#  u'\nbo': 213,
#  u'\nc': 214,
#  u'\nc\n': 215,
#  u'\nca': 216,
#  u'\ncc': 217,
#  u'\nch': 218,
#  u'\nco': 219,
#  u'\nd': 220,
#  u'\nda': 221,
#  u'\ne': 222,
#  u'\ne\n': 223,
#  u'\nec': 224,
#  u'\nf': 225,
#  u'\nfo': 226,
#  u'\nfr': 227,
#  u'\ni': 228,
#  u'\ni\n': 229,
#  u'\nid': 230,
#  u'\nif': 231,
#  u'\nj': 232,
#  u'\nj\n': 233,
#  u'\nl': 234,
#  u'\nl\n': 235,
#  u'\nli': 236,
#  u'\nm': 237,
#  u'\nma': 238,
#  u'\nn': 239,
#  u'\nna': 240,
#  u'\no': 241,
#  u'\non': 242,
#  u'\np': 243,
#  u'\np\n': 244,
#  u'\npr': 245,
#  u'\nr': 246,
#  u'\nr\n': 247,
#  u'\nrc': 248,
#  u'\ns': 249,
#  u'\ns\n': 250,
#  u'\nse': 251,
#  u'\nsr': 252,
#  u'\nsu': 253,
#  u'\nt': 254,
#  u'\nt\n': 255,
#  u'\nto': 256,
#  u'\nu': 257,
#  u'\nun': 258,
#  u'\nv': 259,
#  u'\nv\n': 260,
#  u'\nve': 261,
#  u'\nx': 262,
#  u'\nx\n': 263,
#  u'\n|': 264,
#  u'\n|(': 265,
#  u'\x0b': 266,
#  u"\x0b'": 267,
#  u"\x0b''": 268,
#  u'\x0b1': 269,
#  u'\x0b1,': 270,
#  u'\x0b=': 271,
#  u'\x0b=l': 272,
#  u'\x0b=p': 273,
#  u'\x0b[': 274,
#  u'\x0b[\\': 275,
#  u'\x0ba': 276,
#  u'\x0baa': 277,
#  u'\x0bal': 278,
#  u'\x0ban': 279,
#  u'\x0bc': 280,
#  u'\x0bch': 281,
#  u'\x0bo': 282,
#  u'\x0bon': 283,
#  u'\x0bs': 284,
#  u'\x0bse': 285,
#  u'\x0bu': 286,
#  u'\x0bun': 287,
#  u'\x0c': 288,
#  u"\x0c'": 289,
#  u"\x0c''": 290,
#  u'\x0c+': 291,
#  u'\x0c+~': 292,
#  u'\x0c1': 293,
#  u'\x0c1,': 294,
#  u'\x0c?': 295,
#  u'\x0c?a': 296,
#  u'\x0ca': 297,
#  u'\x0caa': 298,
#  u'\x0can': 299,
#  u'\x0co': 300,
#  u'\x0con': 301,
#  u'\x0cs': 302,
#  u'\x0cse': 303,
#  u'\x0cu': 304,
#  u'\x0cun': 305,
#  u'\r': 306,
#  u'\r#': 307,
#  u'\r#<': 308,
#  u"\r'": 309,
#  u"\r''": 310,
#  u'\r(': 311,
#  u'\r(0': 312,
#  u'\r(1': 313,
#  u'\r1': 314,
#  u'\r1,': 315,
#  u'\ra': 316,
#  u'\raa': 317,
#  u'\ran': 318,
#  u'\ras': 319,
#  u'\rc': 320,
#  u'\rco': 321,
#  u'\ro': 322,
#  u'\ron': 323,
#  u'\rs': 324,
#  u'\rse': 325,
#  u'\ru': 326,
#  u'\run': 327,
#  u'\x14': 328,
#  u'\x14%': 329,
#  u'\x14% ': 330,
#  u'\x16': 331,
#  u'\x16 ': 332,
#  u'\x18': 333,
#  u'\x18 ': 334,
#  u'\x18 o': 335,
#  u'\x1b': 336,
#  u'\x1b$': 337,
#  u'\x1b$*': 338,
#  u'\x1b(': 339,
#  u'\x1b(j': 340,
#  u'\x1bn': 341,
#  u'\x1bn&': 342,
#  u'\x1f': 343,
#  u'\x1f\x08': 344,
#  u'\x1f\x08\x00': 345,
#  u' ': 346,
#  u' \x00': 347,
#  u' \x00 ': 348,
#  u' \x00>': 349,
#  u' \x16': 350,
#  u' \x16 ': 351,
#  u' !': 352,
#  u' ! ': 353,
#  u' !!': 354,
#  u' !-': 355,
#  u' !/': 356,
#  u' !=': 357,
#  u' !i': 358,
#  u' "': 359,
#  u' " ': 360,
#  u' ""': 361,
#  u' "\'': 362,
#  u' "(': 363,
#  u' ".': 364,
#  u' "/': 365,
#  u' "1': 366,
#  u' "<': 367,
#  u' ">': 368,
#  u' "\\': 369,
#  u' "a': 370,
#  u' "c': 371,
#  u' "d': 372,
#  u' "f': 373,
#  u' "h': 374,
#  u' "i': 375,
#  u' "j': 376,
#  u' "l': 377,
#  u' "p': 378,
#  u' "s': 379,
#  u' "t': 380,
#  u' "v': 381,
#  u' "x': 382,
#  u' "y': 383,
#  u' "z': 384,
#  u' #': 385,
#  u' # ': 386,
#  u' #"': 387,
#  u' #0': 388,
#  u' #1': 389,
#  u' #2': 390,
#  u' #3': 391,
#  u' #r': 392,
#  u' #x': 393,
#  u' #y': 394,
#  u' $': 395,
#  u' $ ': 396,
#  u' $$': 397,
#  u' $(': 398,
#  u' $/': 399,
#  u' $1': 400,
#  u' $2': 401,
#  u' $3': 402,
#  u' $5': 403,
#  u' $_': 404,
#  u' $h': 405,
#  u' ${': 406,
#  u' %': 407,
#  u' % ': 408,
#  u' %&': 409,
#  u' %1': 410,
#  u' %2': 411,
#  u' %3': 412,
#  u' %5': 413,
#  u' %7': 414,
#  u' %>': 415,
#  u' %a': 416,
#  u' %b': 417,
#  u' %c': 418,
#  u' %d': 419,
#  u' %l': 420,
#  u' %r': 421,
#  u' %s': 422,
#  u' %u': 423,
#  u' %y': 424,
#  u' &': 425,
#  u' & ': 426,
#  u' &#': 427,
#  u' &&': 428,
#  u' &;': 429,
#  u' &a': 430,
#  u' &c': 431,
#  u' &g': 432,
#  u' &l': 433,
#  u' &n': 434,
#  u' &p': 435,
#  u" '": 436,
#  u" ' ": 437,
#  u' \'"': 438,
#  u" '%": 439,
#  u" '&": 440,
#  u" ''": 441,
#  u" '(": 442,
#  u" ')": 443,
#  u" '*": 444,
#  u" '+": 445,
#  u" ',": 446,
#  u" '-": 447,
#  u" '.": 448,
#  u" '/": 449,
#  u" '0": 450,
#  u" '1": 451,
#  u" '7": 452,
#  u" ';": 453,
#  u" '<": 454,
#  u" '=": 455,
#  u" '>": 456,
#  u" '\\": 457,
#  u" 'a": 458,
#  u" 'b": 459,
#  u" 'c": 460,
#  u" 'd": 461,
#  u" 'e": 462,
#  u" 'g": 463,
#  u" 'h": 464,
#  u" 'i": 465,
#  u" 'j": 466,
#  u" 'k": 467,
#  u" 'm": 468,
#  u" 'n": 469,
#  u" 'o": 470,
#  u" 'p": 471,
#  u" 'r": 472,
#  u" 's": 473,
#  u" 't": 474,
#  u" 'u": 475,
#  u" 'w": 476,
#  u" 'x": 477,
#  u' (': 478,
#  u' ( ': 479,
#  u' (!': 480,
#  u' ("': 481,
#  u" ('": 482,
#  u' ()': 483,
#  u' (1': 484,
#  u' (2': 485,
#  u' (3': 486,
#  u' (4': 487,
#  u' (5': 488,
#  u' (6': 489,
#  u' (7': 490,
#  u' (8': 491,
#  u' (9': 492,
#  u' (@': 493,
#  u' ([': 494,
#  u' (\\': 495,
#  u' (_': 496,
#  u' (a': 497,
#  u' (b': 498,
#  u' (c': 499,
#  u' (d': 500,
#  u' (e': 501,
#  u' (f': 502,
#  u' (g': 503,
#  u' (h': 504,
#  u' (i': 505,
#  u' (j': 506,
#  u' (l': 507,
#  u' (m': 508,
#  u' (n': 509,
#  u' (o': 510,
#  u' (p': 511,
#  u' (r': 512,
#  u' (s': 513,
#  u' (t': 514,
#  u' (u': 515,
#  u' (v': 516,
#  u' (w': 517,
#  u' (x': 518,
#  u' )': 519,
#  u' ) ': 520,
#  u' )(': 521,
#  u' ),': 522,
#  u' )/': 523,
#  u' );': 524,
#  u' *': 525,
#  u' * ': 526,
#  u' **': 527,
#  u' *.': 528,
#  u' */': 529,
#  u' *\\': 530,
#  u' *c': 531,
#  u' *d': 532,
#  u' *g': 533,
#  u' +': 534,
#  u' + ': 535,
#  u' +<': 536,
#  u' +d': 537,
#  u' ,': 538,
#  u' ,p': 539,
#  u' -': 540,
#  u' - ': 541,
#  u' --': 542,
#  u' -/': 543,
#  u' -0': 544,
#  u' -1': 545,
#  u' -2': 546,
#  u' -6': 547,
#  u' -7': 548,
#  u' -9': 549,
#  u' -a': 550,
#  u' -b': 551,
#  u' -c': 552,
#  u' -d': 553,
#  u' -e': 554,
#  u' -f': 555,
#  u' -g': 556,
#  u' -h': 557,
#  u' -i': 558,
#  u' -j': 559,
#  u' -k': 560,
#  u' -l': 561,
#  u' -m': 562,
#  u' -n': 563,
#  u' -p': 564,
#  u' -r': 565,
#  u' -s': 566,
#  u' -t': 567,
#  u' -u': 568,
#  u' -v': 569,
#  u' -w': 570,
#  u' .': 571,
#  u' . ': 572,
#  u' ..': 573,
#  u' .c': 574,
#  u' .p': 575,
#  u' .w': 576,
#  u' /': 577,
#  u' / ': 578,
#  u' /"': 579,
#  u' /&': 580,
#  u' /*': 581,
#  u' /+': 582,
#  u' /,': 583,
#  u' //': 584,
#  u' /=': 585,
#  u' />': 586,
#  u' /?': 587,
#  u' /a': 588,
#  u' /b': 589,
#  u' /d': 590,
#  u' /e': 591,
#  u' /i': 592,
#  u' /l': 593,
#  u' /o': 594,
#  u' /s': 595,
#  u' /t': 596,
#  u' /w': 597,
#  u' 0': 598,
#  u' 0 ': 599,
#  u' 0+': 600,
#  u' 0,': 601,
#  u' 0-': 602,
#  u' 0/': 603,
#  u' 00': 604,
#  u' 01': 605,
#  u' 02': 606,
#  u' 03': 607,
#  u' 04': 608,
#  u' 05': 609,
#  u' 06': 610,
#  u' 07': 611,
#  u' 08': 612,
#  u' 09': 613,
#  u' 0;': 614,
#  u' 0=': 615,
#  u' 0f': 616,
#  u' 0i': 617,
#  u' 0j': 618,
#  u' 0x': 619,
#  u' 1': 620,
#  u' 1 ': 621,
#  u' 1"': 622,
#  u' 1#': 623,
#  u' 1&': 624,
#  u" 1'": 625,
#  u' 1)': 626,
#  u' 1+': 627,
#  u' 1,': 628,
#  u' 1-': 629,
#  u' 1.': 630,
#  u' 1/': 631,
#  u' 10': 632,
#  u' 11': 633,
#  u' 12': 634,
#  u' 13': 635,
#  u' 14': 636,
#  u' 15': 637,
#  u' 16': 638,
#  u' 17': 639,
#  u' 18': 640,
#  u' 19': 641,
#  u' 1;': 642,
#  u' 1=': 643,
#  u' 1]': 644,
#  u' 1_': 645,
#  u' 1a': 646,
#  u' 1b': 647,
#  u' 1c': 648,
#  u' 1e': 649,
#  u' 1f': 650,
#  u' 1g': 651,
#  u' 1m': 652,
#  u' 1o': 653,
#  u' 1p': 654,
#  u' 1s': 655,
#  u' 1t': 656,
#  u' 1v': 657,
#  u' 1x': 658,
#  u' 2': 659,
#  u' 2 ': 660,
#  u' 2!': 661,
#  u' 2#': 662,
#  u' 2,': 663,
#  u' 2-': 664,
#  u' 2/': 665,
#  u' 20': 666,
#  u' 21': 667,
#  u' 22': 668,
#  u' 23': 669,
#  u' 24': 670,
#  u' 25': 671,
#  u' 26': 672,
#  u' 27': 673,
#  u' 28': 674,
#  u' 29': 675,
#  u' 2=': 676,
#  u' 2>': 677,
#  u' 2_': 678,
#  u' 2a': 679,
#  u' 2c': 680,
#  u' 2d': 681,
#  u' 2e': 682,
#  u' 2g': 683,
#  u' 2i': 684,
#  u' 2k': 685,
#  u' 2m': 686,
#  u' 2n': 687,
#  u' 2o': 688,
#  u' 2p': 689,
#  u' 2s': 690,
#  u' 2t': 691,
#  u' 2v': 692,
#  u' 2x': 693,
#  u' 3': 694,
#  u' 3 ': 695,
#  u' 3#': 696,
#  u' 3-': 697,
#  u' 3.': 698,
#  u' 3/': 699,
#  u' 30': 700,
#  u' 31': 701,
#  u' 32': 702,
#  u' 33': 703,
#  u' 34': 704,
#  u' 35': 705,
#  u' 36': 706,
#  u' 37': 707,
#  u' 38': 708,
#  u' 39': 709,
#  u' 3=': 710,
#  u' 3_': 711,
#  u' 3a': 712,
#  u' 3b': 713,
#  u' 3c': 714,
#  u' 3d': 715,
#  u' 3e': 716,
#  u' 3f': 717,
#  u' 3g': 718,
#  u' 3h': 719,
#  u' 3i': 720,
#  u' 3m': 721,
#  u' 3o': 722,
#  u' 3p': 723,
#  u' 3r': 724,
#  u' 3s': 725,
#  u' 3v': 726,
#  u' 3x': 727,
#  u' 4': 728,
#  u' 4 ': 729,
#  u' 4#': 730,
#  u' 4&': 731,
#  u' 4-': 732,
#  u' 4.': 733,
#  u' 4/': 734,
#  u' 40': 735,
#  u' 41': 736,
#  u' 42': 737,
#  u' 43': 738,
#  u' 44': 739,
#  u' 45': 740,
#  u' 46': 741,
#  u' 47': 742,
#  u' 48': 743,
#  u' 49': 744,
#  u' 4=': 745,
#  u' 4]': 746,
#  u' 4_': 747,
#  u' 4b': 748,
#  u' 4c': 749,
#  u' 4d': 750,
#  u' 4g': 751,
#  u' 4o': 752,
#  u' 4p': 753,
#  u' 4t': 754,
#  u' 4w': 755,
#  u' 4x': 756,
#  u' 5': 757,
#  u' 5 ': 758,
#  u' 5#': 759,
#  u' 5+': 760,
#  u' 5-': 761,
#  u' 5.': 762,
#  u' 5/': 763,
#  u' 50': 764,
#  u' 51': 765,
#  u' 52': 766,
#  u' 53': 767,
#  u' 54': 768,
#  u' 55': 769,
#  u' 56': 770,
#  u' 57': 771,
#  u' 58': 772,
#  u' 59': 773,
#  u' 5=': 774,
#  u' 5_': 775,
#  u' 5c': 776,
#  u' 5e': 777,
#  u' 5f': 778,
#  u' 5m': 779,
#  u' 5p': 780,
#  u' 5s': 781,
#  u' 5t': 782,
#  u' 5x': 783,
#  u' 6': 784,
#  u' 6 ': 785,
#  u' 6#': 786,
#  u' 6-': 787,
#  u' 6/': 788,
#  u' 60': 789,
#  u' 61': 790,
#  u' 62': 791,
#  u' 63': 792,
#  u' 64': 793,
#  u' 65': 794,
#  u' 66': 795,
#  u' 67': 796,
#  u' 68': 797,
#  u' 69': 798,
#  u' 6;': 799,
#  u' 6_': 800,
#  u' 6c': 801,
#  u' 6f': 802,
#  u' 6i': 803,
#  u' 6p': 804,
#  u' 6t': 805,
#  u' 7': 806,
#  u' 7 ': 807,
#  u' 7#': 808,
#  u' 7-': 809,
#  u' 7.': 810,
#  u' 7/': 811,
#  u' 70': 812,
#  u' 71': 813,
#  u' 72': 814,
#  u' 73': 815,
#  u' 74': 816,
#  u' 75': 817,
#  u' 76': 818,
#  u' 77': 819,
#  u' 78': 820,
#  u' 79': 821,
#  u' 7_': 822,
#  u' 7c': 823,
#  u' 7m': 824,
#  u' 7t': 825,
#  u' 7x': 826,
#  u' 8': 827,
#  u' 8 ': 828,
#  u' 8#': 829,
#  u' 8&': 830,
#  u' 8-': 831,
#  u' 8/': 832,
#  u' 80': 833,
#  u' 81': 834,
#  u' 82': 835,
#  u' 83': 836,
#  u' 84': 837,
#  u' 85': 838,
#  u' 86': 839,
#  u' 87': 840,
#  u' 88': 841,
#  u' 89': 842,
#  u' 8_': 843,
#  u' 8d': 844,
#  u' 8i': 845,
#  u' 8o': 846,
#  u' 8t': 847,
#  u' 8x': 848,
#  u' 9': 849,
#  u' 9 ': 850,
#  u' 9#': 851,
#  u' 9&': 852,
#  u' 9,': 853,
#  u' 9-': 854,
#  u' 9/': 855,
#  u' 90': 856,
#  u' 91': 857,
#  u' 92': 858,
#  u' 93': 859,
#  u' 94': 860,
#  u' 95': 861,
#  u' 96': 862,
#  u' 97': 863,
#  u' 98': 864,
#  u' 99': 865,
#  u' 9=': 866,
#  u' 9_': 867,
#  u' 9c': 868,
#  u' 9e': 869,
#  u' 9i': 870,
#  u' 9t': 871,
#  u' 9x': 872,
#  u' 9z': 873,
#  u' :': 874,
#  u' : ': 875,
#  u' :)': 876,
#  u' :-': 877,
#  u' ::': 878,
#  u' :p': 879,
#  u' ;': 880,
#  u' ; ': 881,
#  u' ;&': 882,
#  u' ;c': 883,
#  u' ;i': 884,
#  u' <': 885,
#  u' <\x00': 886,
#  u' < ': 887,
#  u' <!': 888,
#  u' <&': 889,
#  u' </': 890,
#  u' <<': 891,
#  u' <a': 892,
#  u' <b': 893,
#  u' <c': 894,
#  u' <d': 895,
#  u' <f': 896,
#  u' <h': 897,
#  u' <i': 898,
#  u' <l': 899,
#  u' <m': 900,
#  u' <n': 901,
#  u' <o': 902,
#  u' <s': 903,
#  u' <t': 904,
#  u' <x': 905,
#  u' =': 906,
#  u' = ': 907,
#  u' ="': 908,
#  u" ='": 909,
#  u' =1': 910,
#  u' =3': 911,
#  u' ==': 912,
#  u' =[': 913,
#  u' =\\': 914,
#  u' =_': 915,
#  u' =c': 916,
#  u' >': 917,
#  u' > ': 918,
#  u' >&': 919,
#  u' >/': 920,
#  u' >1': 921,
#  u' >;': 922,
#  u' ><': 923,
#  u' >>': 924,
#  u' >?': 925,
#  u' >]': 926,
#  u' >a': 927,
#  u' >c': 928,
#  u' >h': 929,
#  u' >p': 930,
#  u' >q': 931,
#  u' ?': 932,
#  u' ? ': 933,
#  u' ?&': 934,
#  u' ?/': 935,
#  u' ?>': 936,
#  u' ??': 937,
#  u' ?i': 938,
#  u' @': 939,
#  u' @ ': 940,
#  u' @2': 941,
#  u' @@': 942,
#  u' @c': 943,
#  u' @q': 944,
#  u' @s': 945,
#  u' @v': 946,
#  u' @x': 947,
#  u' [': 948,
#  u' [\t': 949,
#  u' [ ': 950,
#  u' [1': 951,
#  u' [2': 952,
#  u' [3': 953,
#  u' [5': 954,
#  u' [7': 955,
#  u' [8': 956,
#  u' [<': 957,
#  u' [a': 958,
#  u' [b': 959,
#  u' [c': 960,
#  u' [d': 961,
#  u' [e': 962,
#  u' [f': 963,
#  u' [h': 964,
#  u' [i': 965,
#  u' [j': 966,
#  u' [k': 967,
#  u' [m': 968,
#  u' [n': 969,
#  u' [p': 970,
#  u' [r': 971,
#  u' [s': 972,
#  u' [t': 973,
#  u' [u': 974,
#  u' [v': 975,
#  u' [w': 976,
#  u' [x': 977,
#  u' [z': 978,
#  u' \\': 979,
#  u' \\ ': 980,
#  u' \\"': 981,
#  u' \\&': 982,
#  u' \\/': 983,
#  u' \\\\': 984,
#  u' \\b': 985,
#  u' \\m': 986,
#  u' \\u': 987,
#  u' \\w': 988,
#  u' \\x': 989,
#  u' ]': 990,
#  u' ] ': 991,
#  u' ];': 992,
#  u' ][': 993,
#  u' ^': 994,
#  u' ^_': 995,
#  u' _': 996,
#  u' _ ': 997,
#  u' _-': 998,
#  u' _/': 999,
#  ...}

# %%
# First, we create a token vocabulary dictionary so that
# we can access tokens by index.
vocab = dict([(v,k) for k,v in vec.vocabulary_.items()])

# %%
term_idx = np.argpartition(term_influence, 1)[0][0]

# %%
print(vocab[term_idx])
# Out:
# t/s

# %%
payload = "<script>alert(1)</script>"

# %%
p.predict([payload])[0]
# Out:
# 1

# %%
p.predict_proba([payload])[0]
# Out:
# array([  2.89279845e-09,   9.99999997e-01])

# %%
p.predict_proba([payload + '/' + vocab[term_idx]])[0]
# Out:
# array([  1.83734699e-07,   9.99999816e-01])

# %%
p.predict_proba([payload + '/' + vocab[term_idx]*258])[0]
# Out:
# array([ 0.50142443,  0.49857557])

# %%
p.predict([payload + '/' + vocab[term_idx]*258])[0]
# Out:
# 0

# %%
print(payload + '/' + vocab[term_idx]*258)
# Out:
# <script>alert(1)</script>...
